# %%
import keras
from keras.models import Sequential, Model
from keras.layers import Dense,Reshape, Input,merge
from keras.layers.merge import concatenate
from keras.layers.core import Activation, Dropout, Flatten,Lambda
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import UpSampling2D,Conv2D, MaxPooling2D,Conv2DTranspose
from keras.layers.advanced_activations import LeakyReLU
from keras.optimizers import SGD
from keras.datasets import mnist
import numpy as np
from math import ceil
from PIL import Image
import matplotlib.pyplot as plt
from facade_dataset import FacadeDataset
from keras import backend as K

from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
train_d = FacadeDataset().dataset
# Out:
# load dataset start
#      from: ./dataset/base/
# load dataset done

# %%
def CBR(ch,shape,bn=True,sample='down',activation=LeakyReLU, dropout=False):
    model = Sequential()
    if sample=='down':
        model.add(Conv2D(filters=ch, kernel_size=(4,4), strides=2, padding='same',input_shape=shape))
    else:
        model.add(Conv2DTranspose(filters=ch, kernel_size=(4,4), strides=2, padding='same',input_shape=shape))
    if bn:
        model.add(BatchNormalization())
    if dropout:
        model.add(Dropout(0.5))
    if activation == LeakyReLU:
        model.add(LeakyReLU(alpha=0.2))
    else:
        model.add(Activation('relu'))
    
    return model

# %%
def PatchGan(patch_size=4):
    p = patch_size
    input1 = Input(shape=(p,p,1))
    input2 = Input(shape=(p,p,3))
    x1 = CBR(32,(p,p,1))(input1)
    x2 = CBR(32,(p,p,3))(input2)
    x = concatenate([x1,x2])
    x = CBR(128,(int(p/2),int(p/2),64))(x)
    x = CBR(256,(int(int(p/2)/2),int(int(p/2)/2),128))(x)
    x = Flatten()(x)
    output = Dense(1,activation='sigmoid')(x)
    model = Model(inputs=[input1,input2], outputs=output)
    return model

# %%
model = PatchGan(4)
SVG(model_to_dot(model).create(prog='dot', format='svg'))

# %%
model.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_38 (InputLayer)            (None, 4, 4, 1)       0
# ____________________________________________________________________________________________________
# input_39 (InputLayer)            (None, 4, 4, 3)       0
# ____________________________________________________________________________________________________
# sequential_51 (Sequential)       (None, 2, 2, 32)      672         input_38[0][0]
# ____________________________________________________________________________________________________
# sequential_52 (Sequential)       (None, 2, 2, 32)      1696        input_39[0][0]
# ____________________________________________________________________________________________________
# concatenate_22 (Concatenate)     (None, 2, 2, 64)      0           sequential_51[1][0]
#                                                                    sequential_52[1][0]
# ____________________________________________________________________________________________________
# sequential_53 (Sequential)       (None, 1, 1, 128)     131712      concatenate_22[0][0]
# ____________________________________________________________________________________________________
# sequential_54 (Sequential)       (None, 1, 1, 256)     525568      sequential_53[1][0]
# ____________________________________________________________________________________________________
# flatten_6 (Flatten)              (None, 256)           0           sequential_54[1][0]
# ____________________________________________________________________________________________________
# dense_13 (Dense)                 (None, 1)             257         flatten_6[0][0]
# ====================================================================================================
# Total params: 659,905
# Trainable params: 659,009
# Non-trainable params: 896
# ____________________________________________________________________________________________________

# %%
def discriminator(patch_size=4):
    h = 256
    w = 256
    ph = patch_size
    pw = patch_size
    gen_output = Input(shape=(h,w,3))
    label_input = Input(shape=(h,w,1))
    list_row_idx = [(i * ph, (i + 1) * ph) for i in range(int(h / ph))]
    list_col_idx = [(i * pw, (i + 1) * pw) for i in range(int(w / pw))]
    pg = PatchGan(patch_size)
    pg_list = []
    
    for row_idx in list_row_idx:
        for col_idx in list_col_idx:
            gen_patch =  Lambda(lambda x: x[:,row_idx[0]:row_idx[1],col_idx[0]:col_idx[1],:])(gen_output)
            img_patch =  Lambda(lambda x: x[:,row_idx[0]:row_idx[1],col_idx[0]:col_idx[1],:])(label_input)
            x = pg([img_patch,gen_patch])
            pg_list.append(x)
    x = concatenate(pg_list)
    output = Dense(1,activation = 'sigmoid')(x)
    model = Model(inputs =[label_input,gen_output], outputs = output)
    
    return model

# %%
dis = discriminator(patch_size=64)
SVG(model_to_dot(dis).create(prog='dot', format='svg'))

# %%
dis.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_45 (InputLayer)            (None, 256, 256, 1)   0
# ____________________________________________________________________________________________________
# input_44 (InputLayer)            (None, 256, 256, 3)   0
# ____________________________________________________________________________________________________
# lambda_194 (Lambda)              (None, 64, 64, 1)     0           input_45[0][0]
# ____________________________________________________________________________________________________
# lambda_193 (Lambda)              (None, 64, 64, 3)     0           input_44[0][0]
# ____________________________________________________________________________________________________
# lambda_196 (Lambda)              (None, 64, 64, 1)     0           input_45[0][0]
# ____________________________________________________________________________________________________
# lambda_195 (Lambda)              (None, 64, 64, 3)     0           input_44[0][0]
# ____________________________________________________________________________________________________
# lambda_198 (Lambda)              (None, 64, 64, 1)     0           input_45[0][0]
# ____________________________________________________________________________________________________
# lambda_197 (Lambda)              (None, 64, 64, 3)     0           input_44[0][0]
# ____________________________________________________________________________________________________
# lambda_200 (Lambda)              (None, 64, 64, 1)     0           input_45[0][0]
# ____________________________________________________________________________________________________
# lambda_199 (Lambda)              (None, 64, 64, 3)     0           input_44[0][0]
# ____________________________________________________________________________________________________
# lambda_202 (Lambda)              (None, 64, 64, 1)     0           input_45[0][0]
# ____________________________________________________________________________________________________
# lambda_201 (Lambda)              (None, 64, 64, 3)     0           input_44[0][0]
# ____________________________________________________________________________________________________
# lambda_204 (Lambda)              (None, 64, 64, 1)     0           input_45[0][0]
# ____________________________________________________________________________________________________
# lambda_203 (Lambda)              (None, 64, 64, 3)     0           input_44[0][0]
# ____________________________________________________________________________________________________
# lambda_206 (Lambda)              (None, 64, 64, 1)     0           input_45[0][0]
# ____________________________________________________________________________________________________
# lambda_205 (Lambda)              (None, 64, 64, 3)     0           input_44[0][0]
# ____________________________________________________________________________________________________
# lambda_208 (Lambda)              (None, 64, 64, 1)     0           input_45[0][0]
# ____________________________________________________________________________________________________
# lambda_207 (Lambda)              (None, 64, 64, 3)     0           input_44[0][0]
# ____________________________________________________________________________________________________
# lambda_210 (Lambda)              (None, 64, 64, 1)     0           input_45[0][0]
# ____________________________________________________________________________________________________
# lambda_209 (Lambda)              (None, 64, 64, 3)     0           input_44[0][0]
# ____________________________________________________________________________________________________
# lambda_212 (Lambda)              (None, 64, 64, 1)     0           input_45[0][0]
# ____________________________________________________________________________________________________
# lambda_211 (Lambda)              (None, 64, 64, 3)     0           input_44[0][0]
# ____________________________________________________________________________________________________
# lambda_214 (Lambda)              (None, 64, 64, 1)     0           input_45[0][0]
# ____________________________________________________________________________________________________
# lambda_213 (Lambda)              (None, 64, 64, 3)     0           input_44[0][0]
# ____________________________________________________________________________________________________
# lambda_216 (Lambda)              (None, 64, 64, 1)     0           input_45[0][0]
# ____________________________________________________________________________________________________
# lambda_215 (Lambda)              (None, 64, 64, 3)     0           input_44[0][0]
# ____________________________________________________________________________________________________
# lambda_218 (Lambda)              (None, 64, 64, 1)     0           input_45[0][0]
# ____________________________________________________________________________________________________
# lambda_217 (Lambda)              (None, 64, 64, 3)     0           input_44[0][0]
# ____________________________________________________________________________________________________
# lambda_220 (Lambda)              (None, 64, 64, 1)     0           input_45[0][0]
# ____________________________________________________________________________________________________
# lambda_219 (Lambda)              (None, 64, 64, 3)     0           input_44[0][0]
# ____________________________________________________________________________________________________
# lambda_222 (Lambda)              (None, 64, 64, 1)     0           input_45[0][0]
# ____________________________________________________________________________________________________
# lambda_221 (Lambda)              (None, 64, 64, 3)     0           input_44[0][0]
# ____________________________________________________________________________________________________
# lambda_224 (Lambda)              (None, 64, 64, 1)     0           input_45[0][0]
# ____________________________________________________________________________________________________
# lambda_223 (Lambda)              (None, 64, 64, 3)     0           input_44[0][0]
# ____________________________________________________________________________________________________
# model_18 (Model)                 (None, 1)             676033      lambda_194[0][0]
#                                                                    lambda_193[0][0]
#                                                                    lambda_196[0][0]
#                                                                    lambda_195[0][0]
#                                                                    lambda_198[0][0]
#                                                                    lambda_197[0][0]
#                                                                    lambda_200[0][0]
#                                                                    lambda_199[0][0]
#                                                                    lambda_202[0][0]
#                                                                    lambda_201[0][0]
#                                                                    lambda_204[0][0]
#                                                                    lambda_203[0][0]
#                                                                    lambda_206[0][0]
#                                                                    lambda_205[0][0]
#                                                                    lambda_208[0][0]
#                                                                    lambda_207[0][0]
#                                                                    lambda_210[0][0]
#                                                                    lambda_209[0][0]
#                                                                    lambda_212[0][0]
#                                                                    lambda_211[0][0]
#                                                                    lambda_214[0][0]
#                                                                    lambda_213[0][0]
#                                                                    lambda_216[0][0]
#                                                                    lambda_215[0][0]
#                                                                    lambda_218[0][0]
#                                                                    lambda_217[0][0]
#                                                                    lambda_220[0][0]
#                                                                    lambda_219[0][0]
#                                                                    lambda_222[0][0]
#                                                                    lambda_221[0][0]
#                                                                    lambda_224[0][0]
#                                                                    lambda_223[0][0]
# ____________________________________________________________________________________________________
# concatenate_26 (Concatenate)     (None, 16)            0           model_18[1][0]
#                                                                    model_18[2][0]
#                                                                    model_18[3][0]
#                                                                    model_18[4][0]
#                                                                    model_18[5][0]
#                                                                    model_18[6][0]
#                                                                    model_18[7][0]
#                                                                    model_18[8][0]
#                                                                    model_18[9][0]
#                                                                    model_18[10][0]
#                                                                    model_18[11][0]
#                                                                    model_18[12][0]
#                                                                    model_18[13][0]
#                                                                    model_18[14][0]
#                                                                    model_18[15][0]
#                                                                    model_18[16][0]
# ____________________________________________________________________________________________________
# dense_17 (Dense)                 (None, 1)             17          concatenate_26[0][0]
# ====================================================================================================
# Total params: 676,050
# Trainable params: 675,154
# Non-trainable params: 896
# ____________________________________________________________________________________________________

# %%
def generator():
    
    # encoder
    input1 = Input(shape=(256,256,1))
    enc_1 = Conv2D(filters=64, kernel_size=(3,3), strides=1, padding='same',input_shape=(256,256,1))(input1)
    enc_2 = CBR(128,(256,256,64))(enc_1)
    enc_3 = CBR(256,(128,128,128))(enc_2)
    enc_4 = CBR(512,(64,64,256))(enc_3)
    enc_5 = CBR(512,(32,32,512))(enc_4)
    enc_6 = CBR(512,(16,16,512))(enc_5)
    enc_7 = CBR(512,(8,8,512))(enc_6)
    enc_8 = CBR(512,(4,4,512))(enc_7)
    
    # decoder
    x = CBR(512,(2,2,512),sample='up',activation='relu',dropout=True)(enc_8)
    x = CBR(512,(4,4,1024),sample='up',activation='relu',dropout=True)(concatenate([x,enc_7]))
    x = CBR(512,(8,8,1024),sample='up',activation='relu',dropout=True)(concatenate([x,enc_6]))
    x = CBR(512,(16,16,1024),sample='up',activation='relu',dropout=True)(concatenate([x,enc_5]))
    x = CBR(256,(32,32,1024),sample='up',activation='relu',dropout=True)(concatenate([x,enc_4]))
    
    x = CBR(128,(64,64,512),sample='up',activation='relu',dropout=True)(concatenate([x,enc_3]))
    x = CBR(64,(128,128,256),sample='up',activation='relu',dropout=True)(concatenate([x,enc_2]))
    output = Conv2D(filters=3, kernel_size=(3,3),strides=1,padding="same")(concatenate([x,enc_1]))
     
    model = Model(inputs=input1, outputs=output)
    return(model)

# %%
gen = generator()
SVG(model_to_dot(gen).create(prog='dot', format='svg'))

# %%
gen.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_48 (InputLayer)            (None, 256, 256, 1)   0
# ____________________________________________________________________________________________________
# conv2d_58 (Conv2D)               (None, 256, 256, 64)  640         input_48[0][0]
# ____________________________________________________________________________________________________
# sequential_63 (Sequential)       (None, 128, 128, 128) 131712      conv2d_58[0][0]
# ____________________________________________________________________________________________________
# sequential_64 (Sequential)       (None, 64, 64, 256)   525568      sequential_63[1][0]
# ____________________________________________________________________________________________________
# sequential_65 (Sequential)       (None, 32, 32, 512)   2099712     sequential_64[1][0]
# ____________________________________________________________________________________________________
# sequential_66 (Sequential)       (None, 16, 16, 512)   4196864     sequential_65[1][0]
# ____________________________________________________________________________________________________
# sequential_67 (Sequential)       (None, 8, 8, 512)     4196864     sequential_66[1][0]
# ____________________________________________________________________________________________________
# sequential_68 (Sequential)       (None, 4, 4, 512)     4196864     sequential_67[1][0]
# ____________________________________________________________________________________________________
# sequential_69 (Sequential)       (None, 2, 2, 512)     4196864     sequential_68[1][0]
# ____________________________________________________________________________________________________
# sequential_70 (Sequential)       (None, 4, 4, 512)     4196864     sequential_69[1][0]
# ____________________________________________________________________________________________________
# concatenate_27 (Concatenate)     (None, 4, 4, 1024)    0           sequential_70[1][0]
#                                                                    sequential_68[1][0]
# ____________________________________________________________________________________________________
# sequential_71 (Sequential)       (None, 8, 8, 512)     8391168     concatenate_27[0][0]
# ____________________________________________________________________________________________________
# concatenate_28 (Concatenate)     (None, 8, 8, 1024)    0           sequential_71[1][0]
#                                                                    sequential_67[1][0]
# ____________________________________________________________________________________________________
# sequential_72 (Sequential)       (None, 16, 16, 512)   8391168     concatenate_28[0][0]
# ____________________________________________________________________________________________________
# concatenate_29 (Concatenate)     (None, 16, 16, 1024)  0           sequential_72[1][0]
#                                                                    sequential_66[1][0]
# ____________________________________________________________________________________________________
# sequential_73 (Sequential)       (None, 32, 32, 512)   8391168     concatenate_29[0][0]
# ____________________________________________________________________________________________________
# concatenate_30 (Concatenate)     (None, 32, 32, 1024)  0           sequential_73[1][0]
#                                                                    sequential_65[1][0]
# ____________________________________________________________________________________________________
# sequential_74 (Sequential)       (None, 64, 64, 256)   4195584     concatenate_30[0][0]
# ____________________________________________________________________________________________________
# concatenate_31 (Concatenate)     (None, 64, 64, 512)   0           sequential_74[1][0]
#                                                                    sequential_64[1][0]
# ____________________________________________________________________________________________________
# sequential_75 (Sequential)       (None, 128, 128, 128) 1049216     concatenate_31[0][0]
# ____________________________________________________________________________________________________
# concatenate_32 (Concatenate)     (None, 128, 128, 256) 0           sequential_75[1][0]
#                                                                    sequential_63[1][0]
# ____________________________________________________________________________________________________
# sequential_76 (Sequential)       (None, 256, 256, 64)  262464      concatenate_32[0][0]
# ____________________________________________________________________________________________________
# concatenate_33 (Concatenate)     (None, 256, 256, 128) 0           sequential_76[1][0]
#                                                                    conv2d_58[0][0]
# ____________________________________________________________________________________________________
# conv2d_66 (Conv2D)               (None, 256, 256, 3)   3459        concatenate_33[0][0]
# ====================================================================================================
# Total params: 54,426,179
# Trainable params: 54,415,299
# Non-trainable params: 10,880
# ____________________________________________________________________________________________________

# %%
def GAN(generator, discriminator,  patch_size=4):

    gen_input = Input(shape=(256,256,1))
    img_input = Input(shape=(256,256,3))
    
    generated_image = generator(gen_input)


    DCGAN_output = discriminator([gen_input,img_input])

    DCGAN = Model(inputs=[gen_input,img_input],outputs=[generated_image, DCGAN_output],name="DCGAN")

    return DCGAN

# %%
gan = GAN(gen,dis)
SVG(model_to_dot(gan).create(prog='dot', format='svg'))

# %%
gan.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_49 (InputLayer)            (None, 256, 256, 1)   0
# ____________________________________________________________________________________________________
# input_50 (InputLayer)            (None, 256, 256, 3)   0
# ____________________________________________________________________________________________________
# model_20 (Model)                 (None, 256, 256, 3)   54426179    input_49[0][0]
# ____________________________________________________________________________________________________
# model_19 (Model)                 (None, 1)             676050      input_49[0][0]
#                                                                    input_50[0][0]
# ====================================================================================================
# Total params: 55,102,229
# Trainable params: 55,090,453
# Non-trainable params: 11,776
# ____________________________________________________________________________________________________

# %%
train_label = np.concatenate([train_d[0][1][np.newaxis,:,:,np.newaxis],train_d[1][1][np.newaxis,:,:,np.newaxis]],axis=0)
train_img = np.concatenate([train_d[0][0][np.newaxis,:,:],train_d[1][0][np.newaxis,:,:]],axis=0)

# %%
gan_pre = gan.predict([train_label,train_img])
print(gan_pre[1])
# Out:
# [[ 0.62627709]
#  [ 0.62456101]]

# %%
gan_pre[1].reshape(2)
# Out:
# array([ 0.62627709,  0.62456101], dtype=float32)

# %%
import tensorflow as tf
sess = K.get_session()
y_true = tf.Variable(np.array([0.0,1.0]))
y_pred = tf.Variable(gan_pre[1].astype(np.float64).reshape(2))
init_run = tf.global_variables_initializer()
sess.run(init_run)
sess.run(K.binary_crossentropy(y_pred,y_true))
# Out:
# array([ 0.98424064,  0.47070626])

# %%
np.log(0.62456101)
# Out:
# -0.47070626003294369

# %%
train_x = np.concatenate([train_d[0][1][np.newaxis,:,:,np.newaxis],train_d[1][1][np.newaxis,:,:,np.newaxis]],axis=0)

# %%
def discriminator_on_generator_loss(y_true,y_pred):
    return K.mean(K.binary_crossentropy(y_pred,y_true), axis=(1,2,3))

# %%
import tensorflow as tf
sess = K.get_session()
y_true = tf.Variable(np.array([0.0,1.0,0.0]))
y_pred = tf.Variable(np.array([0.2,0.8,0.3]))
init_run = tf.global_variables_initializer()
sess.run(init_run)
sess.run(K.binary_crossentropy(y_pred,y_true))
# Out:
# array([ 0.22314355,  0.22314355,  0.35667494])

# %%
np.log(0.7)
# Out:
# -0.35667494393873245

# %%
sess = K.get_session()
sess.run(K.binary_crossentropy(y_pred,y_true))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-fc09dc0015ed> in <module>()
#       1 sess = K.get_session()
# ----> 2 sess.run(K.binary_crossentropy(y_pred,y_true))
#
# /anaconda/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in binary_crossentropy(output, target, from_logits)
#    2805     if not from_logits:
#    2806         # transform back to logits
# -> 2807         epsilon = _to_tensor(_EPSILON, output.dtype.base_dtype)
#    2808         output = tf.clip_by_value(output, epsilon, 1 - epsilon)
#    2809         output = tf.log(output / (1 - output))
#
# AttributeError: 'numpy.dtype' object has no attribute 'base_dtype'
