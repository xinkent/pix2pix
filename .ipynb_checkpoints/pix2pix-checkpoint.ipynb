# %%
import keras
from keras.models import Sequential, Model
from keras.layers import Dense,Reshape, Input
from keras.layers.merge import concatenate
from keras.layers.core import Activation, Dropout, Flatten
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import UpSampling2D,Conv2D, MaxPooling2D,Conv2DTranspose
from keras.layers.advanced_activations import LeakyReLU
from keras.optimizers import SGD
from keras.datasets import mnist
import numpy as np
from math import ceil
from PIL import Image
import matplotlib.pyplot as plt
from facade_dataset import FacadeDataset

from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
train_d = FacadeDataset().dataset
# Out:
# load dataset start
#      from: ./dataset/base/
# load dataset done

# %%
def CBR(ch,shape,bn=True,sample='down',activation=LeakyReLU, dropout=False):
    model = Sequential()
    if sample=='down':
        model.add(Conv2D(filters=ch, kernel_size=(4,4), strides=2, padding='same',input_shape=shape))
    else:
        model.add(Conv2DTranspose(filters=ch, kernel_size=(4,4), strides=2, padding='same',input_shape=shape))
    if bn:
        model.add(BatchNormalization())
    if dropout:
        model.add(Dropout(0.5))
    if activation == LeakyReLU:
        model.add(LeakyReLU(alpha=0.2))
    else:
        model.add(Activation('relu'))
    
    return model

# %%
def discriminator():
    input1 = Input(shape=(256,256,1))
    input2 = Input(shape=(256,256,3))
    x1 = CBR(32,(256,256,1))(input1)
    x2 = CBR(32,(256,256,3))(input2)
    x = concatenate([x1,x2])
    x = CBR(128,(128,128,64))(x)
    x = CBR(256,(64,64,128))(x)
    x = CBR(512,(32,32,256))(x)
    x = Conv2D(1,3,strides=1,padding='same')(x)
    output = Activation('sigmoid')(x)
    model = Model(inputs=[input1,input2], outputs=output)
    return model

# %%
dis = discriminator()
SVG(model_to_dot(dis).create(prog='dot', format='svg'))

# %%
def encoder():
    model = Sequential()
    model.add(Conv2D(filters=64, kernel_size=(3,3), strides=1, padding='same',input_shape=(32,32,1)))
    model.add(CBR(128,(32,32,64)))
    model.add(CBR(256,(16,16,128)))
    model.add(CBR(512,(8,8,256)))
    model.add(CBR(512,(4,4,512)))
    model.add(CBR(512,(2,2,512)))
    return model

# %%
enc = encoder()
SVG(model_to_dot(enc).create(prog='dot', format='svg'))

# %%
enc.layers
# Out:
# [<keras.layers.convolutional.Conv2D at 0x149c9afd0>,
#  <keras.models.Sequential at 0x149c9a208>,
#  <keras.models.Sequential at 0x149d03748>,
#  <keras.models.Sequential at 0x149eb2cc0>,
#  <keras.models.Sequential at 0x149fe2fd0>,
#  <keras.models.Sequential at 0x14a1286d8>]

# %%
def generator():
    
    # encoder
    input1 = Input(shape=(256,256,1))
    enc_1 = Conv2D(filters=64, kernel_size=(3,3), strides=1, padding='same',input_shape=(256,256,1))(input1)
    enc_2 = CBR(128,(256,256,64))(enc_1)
    enc_3 = CBR(256,(128,128,128))(enc_2)
    enc_4 = CBR(512,(64,64,256))(enc_3)
    enc_5 = CBR(512,(32,32,512))(enc_4)
    enc_6 = CBR(512,(16,16,512))(enc_5)
    enc_7 = CBR(512,(8,8,512))(enc_6)
    enc_8 = CBR(512,(4,4,512))(enc_7)
    
    # decoder
    x = CBR(512,(2,2,512),sample='up',activation='relu',dropout=True)(enc_8)
    x = CBR(512,(4,4,1024),sample='up',activation='relu',dropout=True)(concatenate([x,enc_7]))
    x = CBR(512,(8,8,1024),sample='up',activation='relu',dropout=True)(concatenate([x,enc_6]))
    x = CBR(512,(16,16,1024),sample='up',activation='relu',dropout=True)(concatenate([x,enc_5]))
    x = CBR(256,(32,32,1024),sample='up',activation='relu',dropout=True)(concatenate([x,enc_4]))
    
    x = CBR(128,(64,64,512),sample='up',activation='relu',dropout=True)(concatenate([x,enc_3]))
    x = CBR(64,(128,128,256),sample='up',activation='relu',dropout=True)(concatenate([x,enc_2]))
    output = Conv2D(filters=3, kernel_size=(3,3),strides=1,padding="same")(concatenate([x,enc_1]))
     
    model = Model(inputs=input1, outputs=output)
    return(model)

# %%
gen = generator()
SVG(model_to_dot(gen).create(prog='dot', format='svg'))

# %%
gen.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_4 (InputLayer)             (None, 256, 256, 1)   0
# ____________________________________________________________________________________________________
# conv2d_22 (Conv2D)               (None, 256, 256, 64)  640         input_4[0][0]
# ____________________________________________________________________________________________________
# sequential_26 (Sequential)       (None, 128, 128, 128) 131712      conv2d_22[0][0]
# ____________________________________________________________________________________________________
# sequential_27 (Sequential)       (None, 64, 64, 256)   525568      sequential_26[1][0]
# ____________________________________________________________________________________________________
# sequential_28 (Sequential)       (None, 32, 32, 512)   2099712     sequential_27[1][0]
# ____________________________________________________________________________________________________
# sequential_29 (Sequential)       (None, 16, 16, 512)   4196864     sequential_28[1][0]
# ____________________________________________________________________________________________________
# sequential_30 (Sequential)       (None, 8, 8, 512)     4196864     sequential_29[1][0]
# ____________________________________________________________________________________________________
# sequential_31 (Sequential)       (None, 4, 4, 512)     4196864     sequential_30[1][0]
# ____________________________________________________________________________________________________
# sequential_32 (Sequential)       (None, 2, 2, 512)     4196864     sequential_31[1][0]
# ____________________________________________________________________________________________________
# sequential_33 (Sequential)       (None, 4, 4, 512)     4196864     sequential_32[1][0]
# ____________________________________________________________________________________________________
# concatenate_9 (Concatenate)      (None, 4, 4, 1024)    0           sequential_33[1][0]
#                                                                    sequential_31[1][0]
# ____________________________________________________________________________________________________
# sequential_34 (Sequential)       (None, 8, 8, 512)     8391168     concatenate_9[0][0]
# ____________________________________________________________________________________________________
# concatenate_10 (Concatenate)     (None, 8, 8, 1024)    0           sequential_34[1][0]
#                                                                    sequential_30[1][0]
# ____________________________________________________________________________________________________
# sequential_35 (Sequential)       (None, 16, 16, 512)   8391168     concatenate_10[0][0]
# ____________________________________________________________________________________________________
# concatenate_11 (Concatenate)     (None, 16, 16, 1024)  0           sequential_35[1][0]
#                                                                    sequential_29[1][0]
# ____________________________________________________________________________________________________
# sequential_36 (Sequential)       (None, 32, 32, 512)   8391168     concatenate_11[0][0]
# ____________________________________________________________________________________________________
# concatenate_12 (Concatenate)     (None, 32, 32, 1024)  0           sequential_36[1][0]
#                                                                    sequential_28[1][0]
# ____________________________________________________________________________________________________
# sequential_37 (Sequential)       (None, 64, 64, 256)   4195584     concatenate_12[0][0]
# ____________________________________________________________________________________________________
# concatenate_13 (Concatenate)     (None, 64, 64, 512)   0           sequential_37[1][0]
#                                                                    sequential_27[1][0]
# ____________________________________________________________________________________________________
# sequential_38 (Sequential)       (None, 128, 128, 128) 1049216     concatenate_13[0][0]
# ____________________________________________________________________________________________________
# concatenate_14 (Concatenate)     (None, 128, 128, 256) 0           sequential_38[1][0]
#                                                                    sequential_26[1][0]
# ____________________________________________________________________________________________________
# sequential_39 (Sequential)       (None, 256, 256, 64)  262464      concatenate_14[0][0]
# ____________________________________________________________________________________________________
# concatenate_15 (Concatenate)     (None, 256, 256, 128) 0           sequential_39[1][0]
#                                                                    conv2d_22[0][0]
# ____________________________________________________________________________________________________
# conv2d_30 (Conv2D)               (None, 256, 256, 3)   3459        concatenate_15[0][0]
# ====================================================================================================
# Total params: 54,426,179
# Trainable params: 54,415,299
# Non-trainable params: 10,880
# ____________________________________________________________________________________________________

# %%
train_x = np.concatenate([train_d[0][1][np.newaxis,:,:,np.newaxis],train_d[1][1][np.newaxis,:,:,np.newaxis]],axis=0)

# %%
pre = gen.predict(train_x)

# %%
plt.imshow(pre[1])
